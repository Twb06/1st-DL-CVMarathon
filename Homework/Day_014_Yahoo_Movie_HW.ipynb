# %% [markdown]
# # YAHOO電影爬蟲練習
# ## 練習爬取電影放映資訊。必須逐步獲取電影的代號、放映地區、放映日期後，再送出查詢給伺服器。

# %%
import requests
import re
from bs4 import BeautifulSoup

# %% [markdown]
# ### 先搜尋全部的電影代號(ID)資訊

# %%
# 查看目前上映那些電影，並擷取出其ID資訊
url = 'https://movies.yahoo.com.tw/'
resp = requests.get(url)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
html = soup.find("select", attrs={'name':'movie_id'})
movie_item = html.find_all("option", attrs={'data-name':re.compile('.*')})

for p in movie_item:
    print("Movie: %s, ID: %s" % (p["data-name"], p["value"]))
# Out:
# Movie: 逃出夢幻島, ID: 10485
# Movie: 雨天．紐約, ID: 10476
# Movie: 戰慄魔胎, ID: 10471
# Movie: 殺不了的他與死不了的她, ID: 10467
# Movie: 失控少年兵團, ID: 10456
# Movie: 超＂人＂氣動物園, ID: 10445
# Movie: 就愛斷捨離, ID: 10436
# Movie: 全境失控, ID: 10426
# Movie: 謎夜拼圖, ID: 10418
# Movie: 尋愛夢工廠, ID: 10400
# Movie: 愛情人形, ID: 10394
# Movie: 我的寶貝男孩, ID: 10489
# Movie: 我們的相愛時光, ID: 10460
# Movie: 蜜蜂與遠雷, ID: 10419
# Movie: 電影版 輝夜姬想讓人告白～天才們的戀愛頭腦戰～, ID: 10405
# Movie: 古曼童, ID: 10399
# Movie: 猛禽小隊：小丑女大解放, ID: 10268
# Movie: 鬼魅之家, ID: 10459
# Movie: 熱帶雨, ID: 10448
# Movie: 只想受到你的歡迎, ID: 10411
# Movie: 紅鞋公主與七矮人, ID: 10417
# Movie: 黑水風暴, ID: 10398
# Movie: 1917, ID: 10189
# Movie: 肥龍過江, ID: 10449
# Movie: 你的情歌, ID: 10407
# Movie: 紳士追殺令, ID: 10317
# Movie: 杜立德, ID: 10316
# Movie: 深海終劫站, ID: 10230
# Movie: 她們, ID: 10202
# Movie: 變身特務, ID: 9008
# Movie: 然後我們跳了舞, ID: 10451
# Movie: 在黑暗中漫舞：20週年數位修復版, ID: 10428
# Movie: 不完美的正義, ID: 10243
# Movie: 絕地戰警FOR LIFE, ID: 10242
# Movie: 星星知我心, ID: 10409
# Movie: 重磅腥聞, ID: 10320
# Movie: 兔嘲男孩, ID: 10283
# Movie: 吹哨人, ID: 10381
# Movie: 潛艦追緝, ID: 10333
# Movie: 白頭山：半島浩劫, ID: 10354
# Movie: 怨靈古堡, ID: 10356
# Movie: 茱蒂, ID: 10112
# Movie: 燃燒女子的畫像, ID: 10069
# Movie: 黑計畫, ID: 10351
# Movie: 8級警戒, ID: 10323
# Movie: 大說謊家, ID: 10122
# Movie: 布魯克林孤兒, ID: 10224
# Movie: 暴走曼哈頓, ID: 10044
# Movie: 賽道狂人, ID: 10097
# Movie: 82年生的金智英, ID: 10298
# Movie: 冰雪奇緣2, ID: 9597
# Movie: 萬萬沒想到, ID: 10281
# Movie: 救火奶爸, ID: 10164
# Movie: 決戰中途島, ID: 10130
# Movie: 安眠醫生, ID: 10098
# Movie: 魔鬼終結者：黑暗宿命, ID: 10067
# Movie: 絕鯊47：猛鯊出籠, ID: 10214
# Movie: 陪你很久很久, ID: 10160
# Movie: 雙子殺手, ID: 10017
# Movie: 黑魔女2, ID: 10262
# Movie: 江湖無難事, ID: 10241
# Movie: 小丑, ID: 9949
# Movie: 無間行動, ID: 10155
# Movie: 囧媽的極地任務, ID: 7772
# Movie: 返校, ID: 10109
# Movie: 天氣之子, ID: 10091
# Movie: 亂世佳人, ID: 10170
# Movie: 下半場, ID: 9807
# Movie: 從前，有個好萊塢, ID: 9884
# Movie: 寄生上流, ID: 10020
# Movie: 一首搖滾上月球, ID: 4887
# Movie: 錢不夠用2, ID: 3026

# %% [markdown]
# ### 指定你有興趣的電影其ID，然後查詢其放映地區資訊。

# %%
# 參考前一個步驟中擷取到的ID資訊，並指定ID
movie_id = 10189

# %%
url = 'https://movies.yahoo.com.tw/api/v1/areas_by_movie_theater'
payload = {'movie_id':str(movie_id)}

# 模擬一個header
headers = {
    'authority': 'movies.yahoo.com.tw',
    'method': 'GET',
    'path': '/api/v1/areas_by_movie_theater?movie_id=' + str(movie_id),
    'scheme': 'https',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'cookie': 'rxx=9s3x2fws06.1g16irnc&v=1; _ga=GA1.3.2056742944.1551651301; GUC=AQEBAQFczFpdm0IfmwSB&s=AQAAACoo4N5D&g=XMsVBw; BX=4hkdk1decm57t&b=3&s=mr; _ga=GA1.4.2056742944.1551651301; nexagesuid=82843256dd234e8e91aa73f2062f8218; browsed_movie=; avi=eyJpdiI6Im1NeWFJRlVRWDR1endEcGRGUGJUbVE9PSIsInZhbHVlIjoickRpU3JuUytmcGl6cjF5OW0rNU9iZz09IiwibWFjIjoiY2VmY2NkNzZmM2NhNjY5YzlkOTcyNjE5OGEyMzU0NWYxOTdmMDRkMDY3OWNmMmZjOTMxYjc5MjI5N2Q5NGE5MiJ9; cmp=t=1559391030&j=0; _gid=GA1.4.779543841.1559391031; XSRF-TOKEN=%3D; m_s=; _gat=1; nexagesd=10',
    'dnt': '1',
    'mv-authorization': '21835b082e15b91a69b3851eec7b31b82ce82afb',
    'referer': 'https://movies.yahoo.com.tw/',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}
    
resp = requests.get(url, params=payload, headers=headers)
print(resp.json())  # 若有需要，列印出json原始碼

# 這裡回傳的格式是JSON格式的資料，要解析JSON擷取資料
for p in resp.json():
    print('放映地區: {0}, 代號(area_id): {1}'.format(p['title'], p['area_id']))
# Out:
# [{'area_id': 28, 'title': '台北市', 'priority': 150, 'ts_update': 1547519309}, {'area_id': 8, 'title': '新北市', 'priority': 145, 'ts_update': 1547194527}, {'area_id': 16, 'title': '桃園', 'priority': 140, 'ts_update': 1547452573}, {'area_id': 20, 'title': '新竹', 'priority': 135, 'ts_update': 1547452603}, {'area_id': 15, 'title': '苗栗', 'priority': 130, 'ts_update': 1547452620}, {'area_id': 2, 'title': '台中', 'priority': 125, 'ts_update': 1547507368}, {'area_id': 10, 'title': '台南', 'priority': 100, 'ts_update': 1547507403}, {'area_id': 17, 'title': '高雄', 'priority': 95, 'ts_update': 1547507403}]
# 放映地區: 台北市, 代號(area_id): 28
# 放映地區: 新北市, 代號(area_id): 8
# 放映地區: 桃園, 代號(area_id): 16
# 放映地區: 新竹, 代號(area_id): 20
# 放映地區: 苗栗, 代號(area_id): 15
# 放映地區: 台中, 代號(area_id): 2
# 放映地區: 台南, 代號(area_id): 10
# 放映地區: 高雄, 代號(area_id): 17

# %% [markdown]
# ### 指定你想要觀看的放映地區，查詢有上映電影的場次日期

# %%
# 指定放映地區
area_id = 28

# %%
# 向網站發送請求
url = 'https://movies.yahoo.com.tw/movietime_result.html'
payload = {'movie_id':str(movie_id), 'area_id':str(area_id)}
resp = requests.get(url, params=payload)
resp.encoding = 'utf-8'

soup = BeautifulSoup(resp.text, 'lxml')
movie_date = soup.find_all("label", attrs={'for':re.compile("date_[\d]")})

# 列印播放日期
for date in movie_date:
    print("%s %s" % (date.p.string, date.h3.string))
# Out:
# 二月 20
# 二月 21
# 二月 22
# 二月 23
# 二月 24

# %% [markdown]
# ### 最後指定觀看的日期，查詢並列印出放映的電影院、放映類型(數位、3D、IMAX 3D...)、放映時間等資訊。

# %%
# 選定要觀看的日期
date = "2020-02-21"

# %%
# 向網站發送請求，獲取上映的電影院及時間資訊
url = "https://movies.yahoo.com.tw/ajax/pc/get_schedule_by_movie"
payload = {'movie_id':str(movie_id),
           'date':date,
           'area_id':str(area_id),
           'theater_id':'',
           'datetime':'',
           'movie_type_id':''}

resp = requests.get(url, params=payload)
#print(resp.json()['view'])  # 若有需要，列印出json原始碼

soup = BeautifulSoup(resp.json()['view'], 'lxml')
html = soup.find_all("ul", attrs={'data-theater_name':re.compile(".*")})
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <div class="pc-movie-schedule-form">
#    <div class="area_timebox">
#     <div class="area_title">
#      台北市
#     </div>
#     <ul class="area_time _c jq_area_time" data-theater_name="台北新光影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=35" data-theater_url="http://www.skcineplex.com.tw/" id="theater_id_35">
#      <li class="adds">
#       <a href="https://movies.yahoo.com.tw/theater_result.html/id=35">
#        台北新光影城
#       </a>
#       <span>
#        02-23146668
#       </span>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        數位
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="cf2b5aa8132f11e6b767a1b123456789" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="ee944f28d61b4683a9a90c16cbd8e23f" data-movie_date="02.21" data-movie_time="14:30" data-movie_title="1917" data-movie_type="數位" data-session="a79cf2795c4e4763b9455e150dda379a" data-time="1582266600" id="73210083" name="schedule_list" type="radio" value="2020-02-21 14:30:00"/>
#        <label class="select" for="73210083">
#         14:30
#        </label>
#       </div>
#      </li>
#     </ul>
#     <ul class="area_time _c jq_area_time" data-theater_name="台北日新威秀影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=39" data-theater_url="http://www.vscinemas.com.tw/" id="theater_id_39">
#      <li class="adds">
#       <a href="https://movies.yahoo.com.tw/theater_result.html/id=39">
#        台北日新威秀影城
#       </a>
#       <span>
#        02-23315256
#       </span>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        IMAX
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="40288eb0050f542401050f551a8a48c3" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="81cdf77a6f6047e8affdf48604aaca62" data-movie_date="02.21" data-movie_time="12:20" data-movie_title="1917" data-movie_type="IMAX" data-session="e8bc5a7c517442c0a164fad220e8e9ab" data-time="1582258800" id="73208639" name="schedule_list" type="radio" value="2020-02-21 12:20:00"/>
#        <label class="select" for="73208639">
#         12:20
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f551a8a48c3" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="81cdf77a6f6047e8affdf48604aaca62" data-movie_date="02.21" data-movie_time="16:40" data-movie_title="1917" data-movie_type="IMAX" data-session="e2e7b74ff11c41e4b254c80c09a92739" data-time="1582274400" id="73208641" name="schedule_list" type="radio" value="2020-02-21 16:40:00"/>
#        <label class="select" for="73208641">
#         16:40
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f551a8a48c3" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="81cdf77a6f6047e8affdf48604aaca62" data-movie_date="02.21" data-movie_time="21:10" data-movie_title="1917" data-movie_type="IMAX" data-session="00baf6170f8047b1bf09de917a50f38b" data-time="1582290600" id="73208643" name="schedule_list" type="radio" value="2020-02-21 21:10:00"/>
#        <label class="select" for="73208643">
#         21:10
#        </label>
#       </div>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        數位
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="40288eb0050f542401050f551a8a48c3" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="35741a8e15d14a988cb74948140c9229" data-movie_date="02.21" data-movie_time="14:40" data-movie_title="1917" data-movie_type="數位" data-session="bf15bcaa1c5a49c9a87c1784fa73452b" data-time="1582267200" id="73208640" name="schedule_list" type="radio" value="2020-02-21 14:40:00"/>
#        <label class="select" for="73208640">
#         14:40
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f551a8a48c3" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="35741a8e15d14a988cb74948140c9229" data-movie_date="02.21" data-movie_time="19:10" data-movie_title="1917" data-movie_type="數位" data-session="9cce21d7a166491da5e840aebdd0e3c9" data-time="1582283400" id="73208642" name="schedule_list" type="radio" value="2020-02-21 19:10:00"/>
#        <label class="select" for="73208642">
#         19:10
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f551a8a48c3" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="35741a8e15d14a988cb74948140c9229" data-movie_date="02.21" data-movie_time="23:20" data-movie_title="1917" data-movie_type="數位" data-session="da734b3188944062950304783033b614" data-time="1582298400" id="73208644" name="schedule_list" type="radio" value="2020-02-21 23:20:00"/>
#        <label class="select" for="73208644">
#         23:20
#        </label>
#       </div>
#      </li>
#     </ul>
#     <ul class="area_time _c jq_area_time" data-theater_name="台北信義威秀影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=45" data-theater_url="http://www.vscinemas.com.tw/" id="theater_id_45">
#      <li class="adds">
#       <a href="https://movies.yahoo.com.tw/theater_result.html/id=45">
#        台北信義威秀影城
#       </a>
#       <span>
#        02-87805566
#       </span>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        數位
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="42fc9904d5e9423fb6eb896b0dd64b1e" data-movie_date="02.21" data-movie_time="10:00" data-movie_title="1917" data-movie_type="數位" data-session="21d3217c16b84fd8817e309b50d1b3ee" data-time="1582250400" id="73211684" name="schedule_list" type="radio" value="2020-02-21 10:00:00"/>
#        <label class="select" for="73211684">
#         10:00
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="42fc9904d5e9423fb6eb896b0dd64b1e" data-movie_date="02.21" data-movie_time="12:20" data-movie_title="1917" data-movie_type="數位" data-session="2829cf6ef6b14b699fbf32f1776b6007" data-time="1582258800" id="73211685" name="schedule_list" type="radio" value="2020-02-21 12:20:00"/>
#        <label class="select" for="73211685">
#         12:20
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="42fc9904d5e9423fb6eb896b0dd64b1e" data-movie_date="02.21" data-movie_time="13:30" data-movie_title="1917" data-movie_type="數位" data-session="786f5fd568e448cab0f932ed631fbad7" data-time="1582263000" id="73211686" name="schedule_list" type="radio" value="2020-02-21 13:30:00"/>
#        <label class="select" for="73211686">
#         13:30
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="42fc9904d5e9423fb6eb896b0dd64b1e" data-movie_date="02.21" data-movie_time="14:40" data-movie_title="1917" data-movie_type="數位" data-session="3f6c17f3abd14529bd17b77c788bbe9f" data-time="1582267200" id="73211687" name="schedule_list" type="radio" value="2020-02-21 14:40:00"/>
#        <label class="select" for="73211687">
#         14:40
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="42fc9904d5e9423fb6eb896b0dd64b1e" data-movie_date="02.21" data-movie_time="17:00" data-movie_title="1917" data-movie_type="數位" data-session="42812b0e233b461c892e522a686d1ab9" data-time="1582275600" id="73211688" name="schedule_list" type="radio" value="2020-02-21 17:00:00"/>
#        <label class="select" for="73211688">
#         17:00
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="42fc9904d5e9423fb6eb896b0dd64b1e" data-movie_date="02.21" data-movie_time="19:20" data-movie_title="1917" data-movie_type="數位" data-session="1573d799f299401983248bd9f312e4f9" data-time="1582284000" id="73211689" name="schedule_list" type="radio" value="2020-02-21 19:20:00"/>
#        <label class="select" for="73211689">
#         19:20
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="42fc9904d5e9423fb6eb896b0dd64b1e" data-movie_date="02.21" data-movie_time="20:30" data-movie_title="1917" data-movie_type="數位" data-session="14d9b40f5cfb40a09ea510b9c3a76a53" data-time="1582288200" id="73211690" name="schedule_list" type="radio" value="2020-02-21 20:30:00"/>
#        <label class="select" for="73211690">
#         20:30
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="42fc9904d5e9423fb6eb896b0dd64b1e" data-movie_date="02.21" data-movie_time="21:40" data-movie_title="1917" data-movie_type="數位" data-session="63536e16e9f1497e9b3909e572dd2e2d" data-time="1582292400" id="73211691" name="schedule_list" type="radio" value="2020-02-21 21:40:00"/>
#        <label class="select" for="73211691">
#         21:40
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="42fc9904d5e9423fb6eb896b0dd64b1e" data-movie_date="02.21" data-movie_time="22:50" data-movie_title="1917" data-movie_type="數位" data-session="a7bfcafa9a9244b18c8814468eabc566" data-time="1582296600" id="73211692" name="schedule_list" type="radio" value="2020-02-21 22:50:00"/>
#        <label class="select" for="73211692">
#         22:50
#        </label>
#        <input class="gabtn" data-cinema="40288eb0050f542401050f554e7e0674" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="42fc9904d5e9423fb6eb896b0dd64b1e" data-movie_date="02.22" data-movie_time="00:00" data-movie_title="1917" data-movie_type="數位" data-session="b8a3eba232a945108086a7de3b467d1e" data-time="1582300800" id="73211693" name="schedule_list" type="radio" value="2020-02-22 00:00:00"/>
#        <label class="select" for="73211693">
#         00:00
#        </label>
#       </div>
#      </li>
#     </ul>
#     <ul class="area_time _c jq_area_time" data-theater_name="京站威秀影城" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=118" data-theater_url="http://www.vscinemas.com.tw/" id="theater_id_118">
#      <li class="adds">
#       <a href="https://movies.yahoo.com.tw/theater_result.html/id=118">
#        京站威秀影城
#       </a>
#       <span>
#        02-25525511
#       </span>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        數位
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="5f60dacd-45b3-102d-8d74-e400529c" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="1e5ef9d855b84d86af9a287a9167b9e8" data-movie_date="02.21" data-movie_time="11:55" data-movie_title="1917" data-movie_type="數位" data-session="12bebe651be94760a17890a36dec080e" data-time="1582257300" id="73209179" name="schedule_list" type="radio" value="2020-02-21 11:55:00"/>
#        <label class="select" for="73209179">
#         11:55
#        </label>
#        <input class="gabtn" data-cinema="5f60dacd-45b3-102d-8d74-e400529c" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="1e5ef9d855b84d86af9a287a9167b9e8" data-movie_date="02.21" data-movie_time="14:10" data-movie_title="1917" data-movie_type="數位" data-session="9f990c87b9814dacbca2651d865ac634" data-time="1582265400" id="73209180" name="schedule_list" type="radio" value="2020-02-21 14:10:00"/>
#        <label class="select" for="73209180">
#         14:10
#        </label>
#        <input class="gabtn" data-cinema="5f60dacd-45b3-102d-8d74-e400529c" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="1e5ef9d855b84d86af9a287a9167b9e8" data-movie_date="02.21" data-movie_time="19:00" data-movie_title="1917" data-movie_type="數位" data-session="ca1267fa3efa422c95e2eb60fbe84937" data-time="1582282800" id="73209181" name="schedule_list" type="radio" value="2020-02-21 19:00:00"/>
#        <label class="select" for="73209181">
#         19:00
#        </label>
#        <input class="gabtn" data-cinema="5f60dacd-45b3-102d-8d74-e400529c" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="1e5ef9d855b84d86af9a287a9167b9e8" data-movie_date="02.21" data-movie_time="21:20" data-movie_title="1917" data-movie_type="數位" data-session="5d1015a1bca1465db934e41d985d1655" data-time="1582291200" id="73209182" name="schedule_list" type="radio" value="2020-02-21 21:20:00"/>
#        <label class="select" for="73209182">
#         21:20
#        </label>
#        <input class="gabtn" data-cinema="5f60dacd-45b3-102d-8d74-e400529c" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="1e5ef9d855b84d86af9a287a9167b9e8" data-movie_date="02.21" data-movie_time="23:35" data-movie_title="1917" data-movie_type="數位" data-session="adbb895b096b4c68be39e4c7807923b3" data-time="1582299300" id="73209183" name="schedule_list" type="radio" value="2020-02-21 23:35:00"/>
#        <label class="select" for="73209183">
#         23:35
#        </label>
#       </div>
#      </li>
#     </ul>
#     <ul class="area_time _c jq_area_time" data-theater_name="梅花數位影院" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=126" data-theater_url="" id="theater_id_126">
#      <li class="adds">
#       <a href="https://movies.yahoo.com.tw/theater_result.html/id=126">
#        梅花數位影院
#       </a>
#       <span>
#        02-27326968
#       </span>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        數位
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="b020ba50fbc811e58858f2128151146f" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="f048f0d173d747c6bb0ed2b500763bdb" data-movie_date="02.21" data-movie_time="16:50" data-movie_title="1917" data-movie_type="數位" data-session="949432adb7ad4b398613f3f64f63d6e2" data-time="1582275000" id="73204219" name="schedule_list" type="radio" value="2020-02-21 16:50:00"/>
#        <label class="select" for="73204219">
#         16:50
#        </label>
#       </div>
#      </li>
#     </ul>
#     <ul class="area_time _c jq_area_time" data-theater_name="MUVIE CINEMAS台北松仁威秀" data-theater_schedules="https://movies.yahoo.com.tw/theater_result.html/id=254" data-theater_url="https://www.vscinemas.com.tw/vsweb/theater/detail2.aspx?id=23" id="theater_id_254">
#      <li class="adds">
#       <a href="https://movies.yahoo.com.tw/theater_result.html/id=254">
#        MUVIE CINEMAS台北松仁威秀
#       </a>
#       <span>
#        (02)8780-0800
#       </span>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        數位
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="470e99e70b5611eaa91e06ba2bcebcfa" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="c7dc8665417e4ef58ec9f7bf4113946a" data-movie_date="02.21" data-movie_time="10:20" data-movie_title="1917" data-movie_type="數位" data-session="6849006f563e4836993c0101594f420e" data-time="1582251600" id="73210045" name="schedule_list" type="radio" value="2020-02-21 10:20:00"/>
#        <label class="select" for="73210045">
#         10:20
#        </label>
#        <input class="gabtn" data-cinema="470e99e70b5611eaa91e06ba2bcebcfa" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="c7dc8665417e4ef58ec9f7bf4113946a" data-movie_date="02.21" data-movie_time="16:20" data-movie_title="1917" data-movie_type="數位" data-session="3cf1b20c074d41ef9064a57237d356e4" data-time="1582273200" id="73210047" name="schedule_list" type="radio" value="2020-02-21 16:20:00"/>
#        <label class="select" for="73210047">
#         16:20
#        </label>
#        <input class="gabtn" data-cinema="470e99e70b5611eaa91e06ba2bcebcfa" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="c7dc8665417e4ef58ec9f7bf4113946a" data-movie_date="02.21" data-movie_time="18:40" data-movie_title="1917" data-movie_type="數位" data-session="6107ef9252a4459091caabdb37ecb699" data-time="1582281600" id="73210048" name="schedule_list" type="radio" value="2020-02-21 18:40:00"/>
#        <label class="select" for="73210048">
#         18:40
#        </label>
#        <input class="gabtn" data-cinema="470e99e70b5611eaa91e06ba2bcebcfa" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="c7dc8665417e4ef58ec9f7bf4113946a" data-movie_date="02.21" data-movie_time="23:25" data-movie_title="1917" data-movie_type="數位" data-session="f06f36302a28442fa0c70762f28038c8" data-time="1582298700" id="73210050" name="schedule_list" type="radio" value="2020-02-21 23:25:00"/>
#        <label class="select" for="73210050">
#         23:25
#        </label>
#       </div>
#      </li>
#      <li class="taps">
#       <span class="tapR">
#        TITAN
#       </span>
#      </li>
#      <li class="time _c">
#       <div class="input_picker jq_input_picker">
#        <input class="gabtn" data-cinema="470e99e70b5611eaa91e06ba2bcebcfa" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="b594af84f4a241fba19056d482c9f9e7" data-movie_date="02.21" data-movie_time="13:10" data-movie_title="1917" data-movie_type="TITAN" data-session="22f75e0853374826862eca4acdea808c" data-time="1582261800" id="73210046" name="schedule_list" type="radio" value="2020-02-21 13:10:00"/>
#        <label class="select" for="73210046">
#         13:10
#        </label>
#        <input class="gabtn" data-cinema="470e99e70b5611eaa91e06ba2bcebcfa" data-date="1582214400" data-ezding="ezding" data-ga="['電影頁_時刻表', '電影頁_時刻表_場次', '1917']" data-movie="b594af84f4a241fba19056d482c9f9e7" data-movie_date="02.21" data-movie_time="21:35" data-movie_title="1917" data-movie_type="TITAN" data-session="9abed85c545540bfa3be96490926375f" data-time="1582292100" id="73210049" name="schedule_list" type="radio" value="2020-02-21 21:35:00"/>
#        <label class="select" for="73210049">
#         21:35
#        </label>
#       </div>
#      </li>
#     </ul>
#    </div>
#    <div class="booking_modal jq_booking_modal">
#     <div class="booking_modal_backdrop">
#     </div>
#     <!-- 時報訂票 ＆ 有官網訂票 新增 class => no_seats -->
#     <div class="booking_modal_content jq_booking_modal_content">
#      <form action="https://movies.yahoo.com.tw/ticket/ezding_ticket" id="form_schedule" method="get" target="_blank">
#       <div class="ezding_ticket_value">
#        <input name="movie_id" type="hidden" value=""/>
#        <input name="cinema_id" type="hidden" value=""/>
#        <input name="session_id" type="hidden" value=""/>
#        <input name="date" type="hidden" value=""/>
#        <input name="time" type="hidden" value=""/>
#        <input name="campaign_code" type="hidden" value="yahoopc"/>
#       </div>
#       <ul class="top_infos">
#        <li>
#         <p>
#          片名
#         </p>
#         <h3 id="top_infos_movie">
#         </h3>
#        </li>
#        <li>
#         <p>
#          影城
#         </p>
#         <h3 id="top_infos_theater">
#         </h3>
#        </li>
#        <li>
#         <p>
#          日期
#         </p>
#         <h3 id="top_infos_date">
#         </h3>
#        </li>
#        <li>
#         <p>
#          版本
#         </p>
#         <h3 id="top_infos_movie_type">
#         </h3>
#        </li>
#        <li>
#         <p>
#          時間
#         </p>
#         <h3 id="top_infos_time">
#         </h3>
#        </li>
#       </ul>
#       <div class="booking_seats">
#        <a class="theater_schedules gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_全部電影場次', '']" href="#">
#         全部電影場次
#        </a>
#        <a class="theater_url gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_官網訂票', '']" href="#" target="_blank">
#         官網訂票
#        </a>
#        <p class="no_theater_url" id="no_theater_url">
#         無提供官網訂票
#        </p>
#        <p class="booking_number" id="booking_number">
#         人數
#        </p>
#        <div class="booking_seat_group jq_booking_seat_group">
#         <input id="seat_1" name="tickets" type="radio" value="1"/>
#         <label for="seat_1">
#          1
#         </label>
#         <input checked="" id="seat_2" name="tickets" type="radio" value="2"/>
#         <label for="seat_2">
#          2
#         </label>
#         <input id="seat_3" name="tickets" type="radio" value="3"/>
#         <label for="seat_3">
#          3
#         </label>
#         <input id="seat_4" name="tickets" type="radio" value="4"/>
#         <label for="seat_4">
#          4
#         </label>
#         <input id="seat_5" name="tickets" type="radio" value="5"/>
#         <label for="seat_5">
#          5
#         </label>
#         <input id="seat_6" name="tickets" type="radio" value="6"/>
#         <label for="seat_6">
#          6
#         </label>
#        </div>
#        <button class="action_btn action_booking_btn jq_booking_btn gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_一般戲院_選位', '']" type="submit">
#         選位
#        </button>
#        <a class="action_btn action_link jq_booking_link gabtn" data-ga="['電影頁_時刻表', '電影頁_時刻表_時報戲院_官網選位', '']" href="#" target="_blank">
#         官網訂票
#        </a>
#        <button class="action_btn close jq_close_booking_btn" type="button">
#         關閉
#        </button>
#       </div>
#      </form>
#      <!-- 無官網訂票區塊 -->
#      <div class="no_theater_section">
#       <p>
#        無提供官網訂票
#       </p>
#       <button class="action_btn close jq_close_booking_btn" type="button">
#        關閉
#       </button>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
for theater in html:
    print("----------------------------------------------------------------------")
    print("電影院:　{}".format(theater["data-theater_name"]))
    
    for movie_type in theater.find_all(class_ = "tapR"):
        print("放映類型:　{}".format(movie_type.text))
        
        for movie_time in theater.find_all("input", attrs = {"data-movie_type" : movie_type.text}):
            print(movie_time["value"])
# Out:
# ----------------------------------------------------------------------
# 電影院:　台北新光影城
# 放映類型:　數位
# 2020-02-21 14:30:00
# ----------------------------------------------------------------------
# 電影院:　台北日新威秀影城
# 放映類型:　IMAX
# 2020-02-21 12:20:00
# 2020-02-21 16:40:00
# 2020-02-21 21:10:00
# 放映類型:　數位
# 2020-02-21 14:40:00
# 2020-02-21 19:10:00
# 2020-02-21 23:20:00
# ----------------------------------------------------------------------
# 電影院:　台北信義威秀影城
# 放映類型:　數位
# 2020-02-21 10:00:00
# 2020-02-21 12:20:00
# 2020-02-21 13:30:00
# 2020-02-21 14:40:00
# 2020-02-21 17:00:00
# 2020-02-21 19:20:00
# 2020-02-21 20:30:00
# 2020-02-21 21:40:00
# 2020-02-21 22:50:00
# 2020-02-22 00:00:00
# ----------------------------------------------------------------------
# 電影院:　京站威秀影城
# 放映類型:　數位
# 2020-02-21 11:55:00
# 2020-02-21 14:10:00
# 2020-02-21 19:00:00
# 2020-02-21 21:20:00
# 2020-02-21 23:35:00
# ----------------------------------------------------------------------
# 電影院:　梅花數位影院
# 放映類型:　數位
# 2020-02-21 16:50:00
# ----------------------------------------------------------------------
# 電影院:　MUVIE CINEMAS台北松仁威秀
# 放映類型:　數位
# 2020-02-21 10:20:00
# 2020-02-21 16:20:00
# 2020-02-21 18:40:00
# 2020-02-21 23:25:00
# 放映類型:　TITAN
# 2020-02-21 13:10:00
# 2020-02-21 21:35:00
